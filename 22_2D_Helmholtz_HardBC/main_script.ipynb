# %% [markdown]
# ## 问题定义
#
# 本问题为求解2D Helmholtz方程。其形式可以参考案例18中的PDE定义。
#
#
# ### 求解目标
#
# 要求求解给定区域内的Helmholtz方程
#
# ## HardBC
#
# 参考论文：Sukumar, N., and Ankit Srivastava. “Exact imposition of boundary conditions with distance functions in physics-informed deep neural networks.” Computer Methods in Applied Mechanics and Engineering 389 (2022): 114333.
#
# 在一般的训练流程中，所有的定解条件均是以惩罚项的形式添加到损失函数中，也就是软约束。这在一些问题中会影响求解，因为这种情况下无法保证精确满足定解条件。
#
# 这篇文章从模型定义出发，将BC条件编入了模型中，从而保证BC的严格成立。

# %% [markdown]
# ## 求解

# %%
import os
import warnings

# optional
# set appropriate GPU in case of multi-GPU machine
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="6"

# %%
from modulus.sym.hydra import to_yaml
from modulus.sym.hydra.utils import compose
from modulus.sym.utils.io.plotter import ValidatorPlotter, InferencerPlotter

# %%
import torch
import numpy as np
from sympy import Symbol, pi, sin
from typing import List, Tuple, Dict

import modulus.sym
from modulus.sym.hydra import to_absolute_path, instantiate_arch, ModulusConfig
from modulus.sym.utils.io import csv_to_dict
from modulus.sym.solver import Solver
from modulus.sym.domain import Domain
from modulus.sym.geometry.primitives_2d import Rectangle
from modulus.sym.domain.constraint import (
    PointwiseInteriorConstraint,
)
from modulus.sym.domain.validator import PointwiseValidator
from modulus.sym.key import Key
from modulus.sym.node import Node
from modulus.sym.geometry.adf import ADF
from modulus.sym.eq.pdes.wave_equation import HelmholtzEquation

# %%
cfg = compose(config_path="conf", config_name="config")
cfg.network_dir = 'outputs'    # Set the network directory for checkpoints
print(to_yaml(cfg))
# Out:
# /usr/local/lib/python3.10/dist-packages/modulus/sym/hydra/utils.py:148: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   hydra.initialize(
# training:
#   max_steps: 20000
#   grad_agg_freq: 1
#   rec_results_freq: 1000
#   rec_validation_freq: ${training.rec_results_freq}
#   rec_inference_freq: ${training.rec_results_freq}
#   rec_monitor_freq: ${training.rec_results_freq}
#   rec_constraint_freq: 2000
#   save_network_freq: 1000
#   print_stats_freq: 100
#   summary_freq: 1000
#   amp: false
#   amp_dtype: float16
#   ntk:
#     use_ntk: false
#     save_name: null
#     run_freq: 1000
# graph:
#   func_arch: false
#   func_arch_allow_partial_hessian: true
# stop_criterion:
#   metric: null
#   min_delta: null
#   patience: 50000
#   mode: min
#   freq: 1000
#   strict: false
# profiler:
#   profile: false
#   start_step: 0
#   end_step: 100
#   name: nvtx
# network_dir: outputs
# initialization_network_dir: ''
# save_filetypes: vtk,npz
# summary_histograms: false
# jit: true
# jit_use_nvfuser: true
# jit_arch_mode: only_activation
# jit_autograd_nodes: false
# cuda_graphs: false
# cuda_graph_warmup: 20
# find_unused_parameters: false
# broadcast_buffers: false
# device: ''
# debug: false
# run_mode: train
# arch:
#   fully_connected:
#     arch_type: fully_connected
#     input_keys: ???
#     output_keys: ???
#     detach_keys: ???
#     scaling: null
#     layer_size: 512
#     nr_layers: 6
#     skip_connections: false
#     activation_fn: silu
#     adaptive_activations: false
#     weight_norm: true
# models: ???
# loss:
#   _target_: modulus.sym.loss.aggregator.Sum
#   weights: null
# optimizer:
#   _params_:
#     compute_gradients: adam_compute_gradients
#     apply_gradients: adam_apply_gradients
#   _target_: torch.optim.Adam
#   lr: 0.001
#   betas:
#   - 0.9
#   - 0.999
#   eps: 1.0e-08
#   weight_decay: 0.0
#   amsgrad: false
# scheduler:
#   _target_: custom
#   _name_: tf.ExponentialLR
#   decay_rate: 0.95
#   decay_steps: 200
# batch_size:
#   interior: 4000
# custom: ???

# %% [markdown]
# ### 定义必要组件

# %% [markdown]
# #### 计算ADF

# %%
class HardBC(ADF):  # 计算ADF
    def __init__(self):
        super().__init__()

        # domain measures
        # 几何
        self.domain_height: float = 2.0
        self.domain_width: float = 2.0

        # boundary conditions (bottom, right, top, left)
        # 边界条件
        # 本问题是比较简单的Dirichlet BC
        self.g: List[float] = [0.0, 0.0, 0.0, 0.0]

        # parameters
        self.eps: float = 1e-9
        self.mu: float = 2.0
        self.m: float = 2.0

    def forward(self, invar: Dict[str, torch.Tensor]) -> Dict[str, torch.Tensor]:
        """
        Forms the solution anstaz for the Helmholtz example
        """

        outvar = {}
        x, y = invar["x"], invar["y"]
        
        # 四条边的分量
        omega_0 = ADF.line_segment_adf(
            (x, y),
            (-self.domain_width / 2, -self.domain_height / 2),
            (self.domain_width / 2, -self.domain_height / 2),
        )
        omega_1 = ADF.line_segment_adf(
            (x, y),
            (self.domain_width / 2, -self.domain_height / 2),
            (self.domain_width / 2, self.domain_height / 2),
        )
        omega_2 = ADF.line_segment_adf(
            (x, y),
            (self.domain_width / 2, self.domain_height / 2),
            (-self.domain_width / 2, self.domain_height / 2),
        )
        omega_3 = ADF.line_segment_adf(
            (x, y),
            (-self.domain_width / 2, self.domain_height / 2),
            (-self.domain_width / 2, -self.domain_height / 2),
        )
        
        # 计算phi
        omega_E_u = ADF.r_equivalence([omega_0, omega_1, omega_2, omega_3], self.m)

        bases = [
            omega_0**self.mu,
            omega_1**self.mu,
            omega_2**self.mu,
            omega_3**self.mu,
        ]
        w = [
            ADF.transfinite_interpolation(bases, idx, self.eps)
            for idx in range(len(self.g))
        ]
        g = w[0] * self.g[0] + w[1] * self.g[1] + w[2] * self.g[2] + w[3] * self.g[3]
        
        # 模型部分
        outvar["u"] = g + omega_E_u * invar["u_star"]
        return outvar

# %%
hard_bc = HardBC()

# %% [markdown]
# #### Geo

# %%
x, y = Symbol("x"), Symbol("y")
height = hard_bc.domain_height
width = hard_bc.domain_width
rec = Rectangle((-width / 2, -height / 2), (width / 2, height / 2))

# %% [markdown]
# #### PDE

# %%
wave = HelmholtzEquation(u="u", k=1.0, dim=2, mixed_form=True)  # 亥姆霍兹方程，注意这里需要定义mixed_form=True，从而启用first order method

# %% [markdown]
# #### Model

# %%
# 定义简单的全连接网络
# 输入为空间坐标
# 输出为模型预测结果以及对应的一阶项（关于此，请参考官方文档中的first order method）
# https://docs.nvidia.com/deeplearning/modulus/modulus-sym/user_guide/theory/advanced_schemes.html#exact-boundary-condition-imposition
wave_net = instantiate_arch(
    input_keys=[Key("x"), Key("y")],
    output_keys=[Key("u_star"), Key("u_x"), Key("u_y")],
    cfg=cfg.arch.fully_connected,
)

# %% [markdown]
# #### Node

# %%
nodes = (
    wave.make_nodes()  # PDE
    + [Node(inputs=["x", "y", "u_star"], outputs=["u"], evaluate=hard_bc)]  # HardBC
    + [wave_net.make_node(name="wave_network")]  # model
)

# %% [markdown]
# #### Domain

# %%
domain = Domain()

# %% [markdown]
# #### ABC边界
#
# 由于HardBC硬编码，所以不需要引入边界条件

# %% [markdown]
# #### PDE约束

# %%
interior = PointwiseInteriorConstraint(
    nodes=nodes,
    geometry=rec,
    outvar={
        "helmholtz": -(
            -((pi) ** 2) * sin(pi * x) * sin(4 * pi * y)
            - ((4 * pi) ** 2) * sin(pi * x) * sin(4 * pi * y)
            + 1 * sin(pi * x) * sin(4 * pi * y)
        ),  # PDE约束
        "compatibility_u_x": 0,  # 一阶项预测约束
        "compatibility_u_y": 0,  # 一阶项预测约束
    },
    batch_size=cfg.batch_size.interior,
    bounds={x: (-width / 2, width / 2), y: (-height / 2, height / 2)},
    lambda_weighting={
        "helmholtz": Symbol("sdf"),
        "compatibility_u_x": 0.5,
        "compatibility_u_y": 0.5,
    },
)
domain.add_constraint(interior, "interior")

# %% [markdown]
# #### 验证器以及其他必要组件

# %%
file_path = "openfoam/helmholtz.csv"
if os.path.exists(to_absolute_path(file_path)):
    mapping = {"x": "x", "y": "y", "z": "u"}
    openfoam_var = csv_to_dict(to_absolute_path(file_path), mapping)
    openfoam_invar_numpy = {
        key: value for key, value in openfoam_var.items() if key in ["x", "y"]
    }
    openfoam_outvar_numpy = {
        key: value for key, value in openfoam_var.items() if key in ["u"]
    }

    openfoam_validator = PointwiseValidator(
        nodes=nodes,
        invar=openfoam_invar_numpy,
        true_outvar=openfoam_outvar_numpy,
        batch_size=1024,
        plotter=ValidatorPlotter(),
    )
    domain.add_validator(openfoam_validator)
else:
    warnings.warn(
        f"Directory {file_path} does not exist. Will skip adding validators. Please download the additional files from NGC https://catalog.ngc.nvidia.com/orgs/nvidia/teams/modulus/resources/modulus_sym_examples_supplemental_materials"
    )

# %% [markdown]
# ### 求解器以及求解

# %%
# 定义求解器
slv = Solver(cfg, domain)

# %% [markdown]
# 手动加载日志系统

# %%
import logging
# logging.getLogger().addHandler(logging.StreamHandler())
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# create console handler and set level to debug
ch = logging.StreamHandler()
ch.setLevel(logging.INFO)

# create formatter
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# add formatter to ch
ch.setFormatter(formatter)

# add ch to logger
logger.addHandler(ch)

# %% [markdown]
# 启动求解

# %%
slv.solve()
# Out:
# 2024-03-03 08:04:03,313 - WARNING - Installed PyTorch version 2.2.0a0+81ea7a4 is not TorchScript supported in Modulus. Version 2.1.0a0+4136153 is officially supported.
# 2024-03-03 08:04:03,320 - INFO - attempting to restore from: /workspace/22_2D_Helmholtz_HardBC/outputs
# 2024-03-03 08:04:03,335 - INFO - Success loading optimizer: /workspace/22_2D_Helmholtz_HardBC/outputs/optim_checkpoint.0.pth
# 2024-03-03 08:04:03,342 - INFO - Success loading model: /workspace/22_2D_Helmholtz_HardBC/outputs/wave_network.0.pth
# 2024-03-03 08:04:04,269 - INFO - [step:          0] record constraint batch time:  4.433e-02s
# 2024-03-03 08:04:15,591 - INFO - [step:          0] record validators time:  1.132e+01s
# 2024-03-03 08:04:15,692 - INFO - [step:          0] saved checkpoint to /workspace/22_2D_Helmholtz_HardBC/outputs
# 2024-03-03 08:04:15,695 - INFO - [step:          0] loss:  1.002e+04
# 2024-03-03 08:04:25,220 - INFO - [step:        100] loss:  9.968e+03, time/iteration:  9.524e+01 ms
# 2024-03-03 08:04:34,220 - INFO - [step:        200] loss:  8.575e+02, time/iteration:  8.997e+01 ms
# 2024-03-03 08:04:43,299 - INFO - [step:        300] loss:  3.096e+01, time/iteration:  9.077e+01 ms
# 2024-03-03 08:04:52,914 - INFO - [step:        400] loss:  1.557e+01, time/iteration:  9.613e+01 ms
# 2024-03-03 08:05:01,722 - INFO - [step:        500] loss:  1.606e+01, time/iteration:  8.804e+01 ms
# 2024-03-03 08:05:11,727 - INFO - [step:        600] loss:  1.736e+01, time/iteration:  1.000e+02 ms
# 2024-03-03 08:05:20,106 - INFO - [step:        700] loss:  9.172e+00, time/iteration:  8.375e+01 ms
# 2024-03-03 08:05:29,367 - INFO - [step:        800] loss:  7.096e+00, time/iteration:  9.259e+01 ms
# 2024-03-03 08:05:39,131 - INFO - [step:        900] loss:  8.158e+00, time/iteration:  9.760e+01 ms
# 2024-03-03 08:06:01,044 - INFO - [step:       1000] record validators time:  1.185e+01s
# 2024-03-03 08:06:01,128 - INFO - [step:       1000] saved checkpoint to /workspace/22_2D_Helmholtz_HardBC/outputs
# 2024-03-03 08:06:01,148 - INFO - [step:       1000] loss:  1.787e+00, time/iteration:  2.201e+02 ms
# 2024-03-03 08:06:10,508 - INFO - [step:       1100] loss:  1.633e+00, time/iteration:  9.359e+01 ms
# 2024-03-03 08:06:18,658 - INFO - [step:       1200] loss:  3.076e+00, time/iteration:  8.148e+01 ms
# 2024-03-03 08:06:27,138 - INFO - [step:       1300] loss:  1.195e+00, time/iteration:  8.478e+01 ms
# 2024-03-03 08:06:37,011 - INFO - [step:       1400] loss:  2.770e+00, time/iteration:  9.869e+01 ms
# 2024-03-03 08:06:45,834 - INFO - [step:       1500] loss:  1.955e+00, time/iteration:  8.822e+01 ms
# 2024-03-03 08:06:55,123 - INFO - [step:       1600] loss:  7.031e-01, time/iteration:  9.285e+01 ms
# 2024-03-03 08:07:04,947 - INFO - [step:       1700] loss:  6.359e+00, time/iteration:  9.822e+01 ms
# 2024-03-03 08:07:14,264 - INFO - [step:       1800] loss:  9.961e-01, time/iteration:  9.313e+01 ms
# 2024-03-03 08:07:23,056 - INFO - [step:       1900] loss:  1.446e+00, time/iteration:  8.790e+01 ms
# 2024-03-03 08:07:32,095 - INFO - [step:       2000] record constraint batch time:  7.394e-02s
# 2024-03-03 08:07:44,209 - INFO - [step:       2000] record validators time:  1.211e+01s
# 2024-03-03 08:07:44,315 - INFO - [step:       2000] saved checkpoint to /workspace/22_2D_Helmholtz_HardBC/outputs
# 2024-03-03 08:07:44,317 - INFO - [step:       2000] loss:  3.598e-01, time/iteration:  2.126e+02 ms
# 2024-03-03 08:07:52,938 - INFO - [step:       2100] loss:  6.178e-01, time/iteration:  8.621e+01 ms
# 2024-03-03 08:08:02,116 - INFO - [step:       2200] loss:  8.361e+00, time/iteration:  9.175e+01 ms
# 2024-03-03 08:08:11,342 - INFO - [step:       2300] loss:  3.414e-01, time/iteration:  9.223e+01 ms
# 2024-03-03 08:08:20,524 - INFO - [step:       2400] loss:  2.806e+00, time/iteration:  9.179e+01 ms
# 2024-03-03 08:08:30,312 - INFO - [step:       2500] loss:  1.876e+01, time/iteration:  9.784e+01 ms
# 2024-03-03 08:08:39,898 - INFO - [step:       2600] loss:  3.634e-01, time/iteration:  9.584e+01 ms
# 2024-03-03 08:08:49,208 - INFO - [step:       2700] loss:  2.504e+00, time/iteration:  9.307e+01 ms
# 2024-03-03 08:08:58,466 - INFO - [step:       2800] loss:  3.535e-01, time/iteration:  9.256e+01 ms
# 2024-03-03 08:09:08,360 - INFO - [step:       2900] loss:  3.479e-01, time/iteration:  9.892e+01 ms
# 2024-03-03 08:09:29,870 - INFO - [step:       3000] record validators time:  1.182e+01s
# 2024-03-03 08:09:29,970 - INFO - [step:       3000] saved checkpoint to /workspace/22_2D_Helmholtz_HardBC/outputs
# 2024-03-03 08:09:29,972 - INFO - [step:       3000] loss:  4.106e+00, time/iteration:  2.161e+02 ms
# 2024-03-03 08:09:38,690 - INFO - [step:       3100] loss:  3.248e-01, time/iteration:  8.716e+01 ms
# 2024-03-03 08:09:47,318 - INFO - [step:       3200] loss:  1.359e+00, time/iteration:  8.626e+01 ms
# 2024-03-03 08:09:57,279 - INFO - [step:       3300] loss:  8.288e-01, time/iteration:  9.958e+01 ms
# 2024-03-03 08:10:07,052 - INFO - [step:       3400] loss:  1.361e+00, time/iteration:  9.770e+01 ms
# 2024-03-03 08:10:15,996 - INFO - [step:       3500] loss:  9.772e+00, time/iteration:  8.942e+01 ms
# 2024-03-03 08:10:24,744 - INFO - [step:       3600] loss:  1.531e-01, time/iteration:  8.746e+01 ms
# 2024-03-03 08:10:33,310 - INFO - [step:       3700] loss:  3.366e-01, time/iteration:  8.564e+01 ms
# 2024-03-03 08:10:42,065 - INFO - [step:       3800] loss:  2.667e-01, time/iteration:  8.753e+01 ms
# 2024-03-03 08:10:51,763 - INFO - [step:       3900] loss:  6.387e-01, time/iteration:  9.695e+01 ms
# 2024-03-03 08:11:00,680 - INFO - [step:       4000] record constraint batch time:  6.933e-02s
# 2024-03-03 08:11:12,066 - INFO - [step:       4000] record validators time:  1.138e+01s
# 2024-03-03 08:11:12,167 - INFO - [step:       4000] saved checkpoint to /workspace/22_2D_Helmholtz_HardBC/outputs
# 2024-03-03 08:11:12,169 - INFO - [step:       4000] loss:  8.913e-01, time/iteration:  2.040e+02 ms
# 2024-03-03 08:11:21,524 - INFO - [step:       4100] loss:  6.080e+00, time/iteration:  9.353e+01 ms
# 2024-03-03 08:11:31,049 - INFO - [step:       4200] loss:  1.553e-01, time/iteration:  9.523e+01 ms
# 2024-03-03 08:11:40,443 - INFO - [step:       4300] loss:  2.391e-01, time/iteration:  9.392e+01 ms
# 2024-03-03 08:11:49,412 - INFO - [step:       4400] loss:  3.578e-01, time/iteration:  8.967e+01 ms
# 2024-03-03 08:11:58,034 - INFO - [step:       4500] loss:  3.013e-01, time/iteration:  8.620e+01 ms
# 2024-03-03 08:12:07,334 - INFO - [step:       4600] loss:  8.713e-01, time/iteration:  9.297e+01 ms
# 2024-03-03 08:12:16,698 - INFO - [step:       4700] loss:  2.362e-01, time/iteration:  9.362e+01 ms
# 2024-03-03 08:12:25,575 - INFO - [step:       4800] loss:  1.504e-01, time/iteration:  8.876e+01 ms
# 2024-03-03 08:12:34,581 - INFO - [step:       4900] loss:  1.296e-01, time/iteration:  9.003e+01 ms
# 2024-03-03 08:12:56,142 - INFO - [step:       5000] record validators time:  1.147e+01s
# 2024-03-03 08:12:56,190 - INFO - [step:       5000] saved checkpoint to /workspace/22_2D_Helmholtz_HardBC/outputs
# 2024-03-03 08:12:56,192 - INFO - [step:       5000] loss:  5.840e+00, time/iteration:  2.161e+02 ms
# 2024-03-03 08:13:05,463 - INFO - [step:       5100] loss:  1.028e-01, time/iteration:  9.270e+01 ms
# 2024-03-03 08:13:14,929 - INFO - [step:       5200] loss:  1.652e-01, time/iteration:  9.462e+01 ms
# 2024-03-03 08:13:24,072 - INFO - [step:       5300] loss:  2.177e+00, time/iteration:  9.141e+01 ms
# 2024-03-03 08:13:33,188 - INFO - [step:       5400] loss:  1.097e-01, time/iteration:  9.112e+01 ms
# 2024-03-03 08:13:42,693 - INFO - [step:       5500] loss:  6.004e-01, time/iteration:  9.503e+01 ms
# 2024-03-03 08:13:52,605 - INFO - [step:       5600] loss:  2.427e-01, time/iteration:  9.910e+01 ms
# 2024-03-03 08:14:02,709 - INFO - [step:       5700] loss:  1.683e-01, time/iteration:  1.010e+02 ms
# 2024-03-03 08:14:12,594 - INFO - [step:       5800] loss:  1.196e+00, time/iteration:  9.881e+01 ms
# 2024-03-03 08:14:22,277 - INFO - [step:       5900] loss:  1.299e-01, time/iteration:  9.681e+01 ms
# 2024-03-03 08:14:31,718 - INFO - [step:       6000] record constraint batch time:  8.224e-02s
# 2024-03-03 08:14:43,158 - INFO - [step:       6000] record validators time:  1.144e+01s
# 2024-03-03 08:14:43,253 - INFO - [step:       6000] saved checkpoint to /workspace/22_2D_Helmholtz_HardBC/outputs
# 2024-03-03 08:14:43,256 - INFO - [step:       6000] loss:  6.231e-01, time/iteration:  2.098e+02 ms
# 2024-03-03 08:14:52,748 - INFO - [step:       6100] loss:  2.392e-01, time/iteration:  9.491e+01 ms
# 2024-03-03 08:15:01,492 - INFO - [step:       6200] loss:  1.258e-01, time/iteration:  8.742e+01 ms
# 2024-03-03 08:15:10,968 - INFO - [step:       6300] loss:  6.574e-01, time/iteration:  9.473e+01 ms
# 2024-03-03 08:15:20,802 - INFO - [step:       6400] loss:  4.958e-01, time/iteration:  9.832e+01 ms
# 2024-03-03 08:15:30,172 - INFO - [step:       6500] loss:  1.138e-01, time/iteration:  9.368e+01 ms
# 2024-03-03 08:15:38,398 - INFO - [step:       6600] loss:  2.576e-01, time/iteration:  8.224e+01 ms
# 2024-03-03 08:15:47,070 - INFO - [step:       6700] loss:  1.390e-01, time/iteration:  8.669e+01 ms
# 2024-03-03 08:15:56,589 - INFO - [step:       6800] loss:  2.269e-01, time/iteration:  9.516e+01 ms
# 2024-03-03 08:16:06,210 - INFO - [step:       6900] loss:  5.130e-01, time/iteration:  9.619e+01 ms
# 2024-03-03 08:16:27,637 - INFO - [step:       7000] record validators time:  1.179e+01s
# 2024-03-03 08:16:27,741 - INFO - [step:       7000] saved checkpoint to /workspace/22_2D_Helmholtz_HardBC/outputs
# 2024-03-03 08:16:27,743 - INFO - [step:       7000] loss:  2.259e-01, time/iteration:  2.153e+02 ms
# 2024-03-03 08:16:37,577 - INFO - [step:       7100] loss:  2.664e-01, time/iteration:  9.832e+01 ms
# 2024-03-03 08:16:47,197 - INFO - [step:       7200] loss:  1.473e-01, time/iteration:  9.618e+01 ms
# 2024-03-03 08:16:57,047 - INFO - [step:       7300] loss:  5.916e-02, time/iteration:  9.848e+01 ms
# 2024-03-03 08:17:05,785 - INFO - [step:       7400] loss:  1.975e-01, time/iteration:  8.735e+01 ms
# 2024-03-03 08:17:14,976 - INFO - [step:       7500] loss:  1.493e-01, time/iteration:  9.190e+01 ms
# 2024-03-03 08:17:24,493 - INFO - [step:       7600] loss:  7.789e-02, time/iteration:  9.515e+01 ms
# 2024-03-03 08:17:33,223 - INFO - [step:       7700] loss:  1.512e-01, time/iteration:  8.728e+01 ms
# 2024-03-03 08:17:43,035 - INFO - [step:       7800] loss:  7.750e-01, time/iteration:  9.810e+01 ms
# 2024-03-03 08:17:52,308 - INFO - [step:       7900] loss:  7.497e-02, time/iteration:  9.271e+01 ms
# 2024-03-03 08:18:02,692 - INFO - [step:       8000] record constraint batch time:  9.906e-02s
# 2024-03-03 08:18:14,173 - INFO - [step:       8000] record validators time:  1.148e+01s
# 2024-03-03 08:18:14,277 - INFO - [step:       8000] saved checkpoint to /workspace/22_2D_Helmholtz_HardBC/outputs
# 2024-03-03 08:18:14,279 - INFO - [step:       8000] loss:  9.028e-02, time/iteration:  2.197e+02 ms
# 2024-03-03 08:18:23,818 - INFO - [step:       8100] loss:  1.057e-01, time/iteration:  9.538e+01 ms
# 2024-03-03 08:18:33,375 - INFO - [step:       8200] loss:  1.829e-01, time/iteration:  9.552e+01 ms
# 2024-03-03 08:18:42,492 - INFO - [step:       8300] loss:  2.026e-01, time/iteration:  9.115e+01 ms
# 2024-03-03 08:18:52,164 - INFO - [step:       8400] loss:  5.939e-02, time/iteration:  9.670e+01 ms
# 2024-03-03 08:19:01,133 - INFO - [step:       8500] loss:  8.052e-02, time/iteration:  8.967e+01 ms
# 2024-03-03 08:19:10,567 - INFO - [step:       8600] loss:  2.132e-01, time/iteration:  9.433e+01 ms
# 2024-03-03 08:19:19,678 - INFO - [step:       8700] loss:  9.903e-02, time/iteration:  9.107e+01 ms
# 2024-03-03 08:19:28,208 - INFO - [step:       8800] loss:  7.910e-02, time/iteration:  8.529e+01 ms
# 2024-03-03 08:19:36,781 - INFO - [step:       8900] loss:  1.413e-01, time/iteration:  8.571e+01 ms
# 2024-03-03 08:19:58,753 - INFO - [step:       9000] record validators time:  1.184e+01s
# 2024-03-03 08:19:58,847 - INFO - [step:       9000] saved checkpoint to /workspace/22_2D_Helmholtz_HardBC/outputs
# 2024-03-03 08:19:58,849 - INFO - [step:       9000] loss:  5.304e-02, time/iteration:  2.206e+02 ms
# 2024-03-03 08:20:08,038 - INFO - [step:       9100] loss:  1.352e-01, time/iteration:  9.188e+01 ms
# 2024-03-03 08:20:17,740 - INFO - [step:       9200] loss:  5.891e-02, time/iteration:  9.699e+01 ms
# 2024-03-03 08:20:27,547 - INFO - [step:       9300] loss:  7.346e-02, time/iteration:  9.805e+01 ms
# 2024-03-03 08:20:36,555 - INFO - [step:       9400] loss:  6.044e-02, time/iteration:  9.007e+01 ms
# 2024-03-03 08:20:46,155 - INFO - [step:       9500] loss:  5.142e-02, time/iteration:  9.598e+01 ms
# 2024-03-03 08:20:55,447 - INFO - [step:       9600] loss:  6.870e-02, time/iteration:  9.290e+01 ms
# 2024-03-03 08:21:05,335 - INFO - [step:       9700] loss:  8.872e-02, time/iteration:  9.885e+01 ms
# 2024-03-03 08:21:14,569 - INFO - [step:       9800] loss:  7.491e-02, time/iteration:  9.233e+01 ms
# 2024-03-03 08:21:23,333 - INFO - [step:       9900] loss:  8.644e-02, time/iteration:  8.763e+01 ms
# 2024-03-03 08:21:33,199 - INFO - [step:      10000] record constraint batch time:  9.261e-02s
# 2024-03-03 08:21:45,309 - INFO - [step:      10000] record validators time:  1.211e+01s
# 2024-03-03 08:21:45,407 - INFO - [step:      10000] saved checkpoint to /workspace/22_2D_Helmholtz_HardBC/outputs
# 2024-03-03 08:21:45,408 - INFO - [step:      10000] loss:  4.808e-02, time/iteration:  2.207e+02 ms
# 2024-03-03 08:21:54,445 - INFO - [step:      10100] loss:  6.279e-02, time/iteration:  9.035e+01 ms
# 2024-03-03 08:22:04,400 - INFO - [step:      10200] loss:  4.105e-02, time/iteration:  9.952e+01 ms
# 2024-03-03 08:22:14,382 - INFO - [step:      10300] loss:  8.048e-02, time/iteration:  9.981e+01 ms
# 2024-03-03 08:22:24,243 - INFO - [step:      10400] loss:  1.504e-01, time/iteration:  9.859e+01 ms
# 2024-03-03 08:22:34,007 - INFO - [step:      10500] loss:  4.325e-02, time/iteration:  9.761e+01 ms
# 2024-03-03 08:22:43,173 - INFO - [step:      10600] loss:  8.897e-02, time/iteration:  9.165e+01 ms
# 2024-03-03 08:22:52,126 - INFO - [step:      10700] loss:  6.199e-02, time/iteration:  8.953e+01 ms
# 2024-03-03 08:23:00,920 - INFO - [step:      10800] loss:  7.334e-02, time/iteration:  8.793e+01 ms
# 2024-03-03 08:23:10,870 - INFO - [step:      10900] loss:  4.749e-02, time/iteration:  9.949e+01 ms
# 2024-03-03 08:23:32,927 - INFO - [step:      11000] record validators time:  1.193e+01s
# 2024-03-03 08:23:32,972 - INFO - [step:      11000] saved checkpoint to /workspace/22_2D_Helmholtz_HardBC/outputs
# 2024-03-03 08:23:32,974 - INFO - [step:      11000] loss:  9.800e-02, time/iteration:  2.210e+02 ms
# 2024-03-03 08:23:40,945 - INFO - [step:      11100] loss:  4.905e-02, time/iteration:  7.970e+01 ms
# 2024-03-03 08:23:49,480 - INFO - [step:      11200] loss:  1.321e-01, time/iteration:  8.534e+01 ms
# 2024-03-03 08:23:58,667 - INFO - [step:      11300] loss:  4.313e-02, time/iteration:  9.186e+01 ms
# 2024-03-03 08:24:07,672 - INFO - [step:      11400] loss:  4.779e-02, time/iteration:  9.001e+01 ms
# 2024-03-03 08:24:17,191 - INFO - [step:      11500] loss:  3.811e-02, time/iteration:  9.519e+01 ms
# 2024-03-03 08:24:26,671 - INFO - [step:      11600] loss:  3.921e-02, time/iteration:  9.478e+01 ms
# 2024-03-03 08:24:36,033 - INFO - [step:      11700] loss:  1.452e-01, time/iteration:  9.361e+01 ms
# 2024-03-03 08:24:45,679 - INFO - [step:      11800] loss:  4.080e-02, time/iteration:  9.645e+01 ms
# 2024-03-03 08:24:55,725 - INFO - [step:      11900] loss:  3.519e-02, time/iteration:  1.004e+02 ms
# 2024-03-03 08:25:05,753 - INFO - [step:      12000] record constraint batch time:  8.803e-02s
# 2024-03-03 08:25:17,308 - INFO - [step:      12000] record validators time:  1.155e+01s
# 2024-03-03 08:25:17,404 - INFO - [step:      12000] saved checkpoint to /workspace/22_2D_Helmholtz_HardBC/outputs
# 2024-03-03 08:25:17,406 - INFO - [step:      12000] loss:  3.522e-02, time/iteration:  2.168e+02 ms
# 2024-03-03 08:25:26,913 - INFO - [step:      12100] loss:  3.836e-02, time/iteration:  9.505e+01 ms
# 2024-03-03 08:25:36,032 - INFO - [step:      12200] loss:  3.788e-02, time/iteration:  9.117e+01 ms
# 2024-03-03 08:25:43,426 - INFO - [step:      12300] loss:  4.712e-02, time/iteration:  7.393e+01 ms
# 2024-03-03 08:25:52,517 - INFO - [step:      12400] loss:  6.423e-02, time/iteration:  9.090e+01 ms
# 2024-03-03 08:26:01,738 - INFO - [step:      12500] loss:  4.478e-02, time/iteration:  9.220e+01 ms
# 2024-03-03 08:26:11,763 - INFO - [step:      12600] loss:  3.698e-02, time/iteration:  1.002e+02 ms
# 2024-03-03 08:26:21,668 - INFO - [step:      12700] loss:  3.738e-02, time/iteration:  9.904e+01 ms
# 2024-03-03 08:26:30,305 - INFO - [step:      12800] loss:  4.127e-02, time/iteration:  8.635e+01 ms
# 2024-03-03 08:26:39,415 - INFO - [step:      12900] loss:  3.706e-02, time/iteration:  9.108e+01 ms
# 2024-03-03 08:27:00,985 - INFO - [step:      13000] record validators time:  1.159e+01s
# 2024-03-03 08:27:01,089 - INFO - [step:      13000] saved checkpoint to /workspace/22_2D_Helmholtz_HardBC/outputs
# 2024-03-03 08:27:01,092 - INFO - [step:      13000] loss:  3.540e-02, time/iteration:  2.168e+02 ms
# 2024-03-03 08:27:10,330 - INFO - [step:      13100] loss:  8.292e-02, time/iteration:  9.237e+01 ms
# 2024-03-03 08:27:19,453 - INFO - [step:      13200] loss:  3.396e-02, time/iteration:  9.121e+01 ms
# 2024-03-03 08:27:28,802 - INFO - [step:      13300] loss:  3.243e-02, time/iteration:  9.348e+01 ms
# 2024-03-03 08:27:38,253 - INFO - [step:      13400] loss:  4.114e-02, time/iteration:  9.450e+01 ms
# 2024-03-03 08:27:47,911 - INFO - [step:      13500] loss:  3.243e-02, time/iteration:  9.655e+01 ms
# 2024-03-03 08:27:57,124 - INFO - [step:      13600] loss:  3.772e-02, time/iteration:  9.211e+01 ms
# 2024-03-03 08:28:06,394 - INFO - [step:      13700] loss:  3.568e-02, time/iteration:  9.268e+01 ms
# 2024-03-03 08:28:15,657 - INFO - [step:      13800] loss:  3.227e-02, time/iteration:  9.261e+01 ms
# 2024-03-03 08:28:24,824 - INFO - [step:      13900] loss:  4.774e-02, time/iteration:  9.165e+01 ms
# 2024-03-03 08:28:34,573 - INFO - [step:      14000] record constraint batch time:  8.452e-02s
# 2024-03-03 08:28:46,362 - INFO - [step:      14000] record validators time:  1.179e+01s
# 2024-03-03 08:28:46,403 - INFO - [step:      14000] saved checkpoint to /workspace/22_2D_Helmholtz_HardBC/outputs
# 2024-03-03 08:28:46,404 - INFO - [step:      14000] loss:  4.267e-02, time/iteration:  2.158e+02 ms
# 2024-03-03 08:28:55,249 - INFO - [step:      14100] loss:  3.359e-02, time/iteration:  8.845e+01 ms
# 2024-03-03 08:29:04,830 - INFO - [step:      14200] loss:  3.625e-02, time/iteration:  9.578e+01 ms
# 2024-03-03 08:29:13,509 - INFO - [step:      14300] loss:  3.228e-02, time/iteration:  8.678e+01 ms
# 2024-03-03 08:29:21,930 - INFO - [step:      14400] loss:  3.205e-02, time/iteration:  8.420e+01 ms
# 2024-03-03 08:29:30,987 - INFO - [step:      14500] loss:  3.516e-02, time/iteration:  9.055e+01 ms
# 2024-03-03 08:29:39,510 - INFO - [step:      14600] loss:  3.079e-02, time/iteration:  8.522e+01 ms
# 2024-03-03 08:29:48,064 - INFO - [step:      14700] loss:  4.035e-02, time/iteration:  8.553e+01 ms
# 2024-03-03 08:29:56,883 - INFO - [step:      14800] loss:  2.888e-02, time/iteration:  8.816e+01 ms
# 2024-03-03 08:30:06,468 - INFO - [step:      14900] loss:  2.951e-02, time/iteration:  9.582e+01 ms
# 2024-03-03 08:30:27,907 - INFO - [step:      15000] record validators time:  1.183e+01s
# 2024-03-03 08:30:27,954 - INFO - [step:      15000] saved checkpoint to /workspace/22_2D_Helmholtz_HardBC/outputs
# 2024-03-03 08:30:27,955 - INFO - [step:      15000] loss:  3.634e-02, time/iteration:  2.149e+02 ms
# 2024-03-03 08:30:36,298 - INFO - [step:      15100] loss:  3.329e-02, time/iteration:  8.342e+01 ms
# 2024-03-03 08:30:45,479 - INFO - [step:      15200] loss:  2.702e-02, time/iteration:  9.179e+01 ms
# 2024-03-03 08:30:54,014 - INFO - [step:      15300] loss:  3.402e-02, time/iteration:  8.533e+01 ms
# 2024-03-03 08:31:03,159 - INFO - [step:      15400] loss:  2.950e-02, time/iteration:  9.143e+01 ms
# 2024-03-03 08:31:11,996 - INFO - [step:      15500] loss:  2.720e-02, time/iteration:  8.834e+01 ms
# 2024-03-03 08:31:21,538 - INFO - [step:      15600] loss:  2.958e-02, time/iteration:  9.541e+01 ms
# 2024-03-03 08:31:31,012 - INFO - [step:      15700] loss:  2.725e-02, time/iteration:  9.471e+01 ms
# 2024-03-03 08:31:39,754 - INFO - [step:      15800] loss:  3.385e-02, time/iteration:  8.741e+01 ms
# 2024-03-03 08:31:48,754 - INFO - [step:      15900] loss:  2.694e-02, time/iteration:  8.999e+01 ms
# 2024-03-03 08:31:58,446 - INFO - [step:      16000] record constraint batch time:  6.763e-02s
# 2024-03-03 08:32:10,578 - INFO - [step:      16000] record validators time:  1.213e+01s
# 2024-03-03 08:32:10,664 - INFO - [step:      16000] saved checkpoint to /workspace/22_2D_Helmholtz_HardBC/outputs
# 2024-03-03 08:32:10,667 - INFO - [step:      16000] loss:  2.552e-02, time/iteration:  2.191e+02 ms
# 2024-03-03 08:32:19,500 - INFO - [step:      16100] loss:  3.408e-02, time/iteration:  8.831e+01 ms
# 2024-03-03 08:32:27,592 - INFO - [step:      16200] loss:  2.884e-02, time/iteration:  8.090e+01 ms
# 2024-03-03 08:32:36,472 - INFO - [step:      16300] loss:  2.623e-02, time/iteration:  8.879e+01 ms
# 2024-03-03 08:32:44,513 - INFO - [step:      16400] loss:  3.388e-02, time/iteration:  8.039e+01 ms
# 2024-03-03 08:32:53,393 - INFO - [step:      16500] loss:  2.637e-02, time/iteration:  8.879e+01 ms
# 2024-03-03 08:33:01,535 - INFO - [step:      16600] loss:  2.903e-02, time/iteration:  8.140e+01 ms
# 2024-03-03 08:33:09,864 - INFO - [step:      16700] loss:  2.947e-02, time/iteration:  8.327e+01 ms
# 2024-03-03 08:33:17,888 - INFO - [step:      16800] loss:  2.890e-02, time/iteration:  8.023e+01 ms
# 2024-03-03 08:33:25,996 - INFO - [step:      16900] loss:  3.301e-02, time/iteration:  8.106e+01 ms
# 2024-03-03 08:33:47,137 - INFO - [step:      17000] record validators time:  1.215e+01s
# 2024-03-03 08:33:47,238 - INFO - [step:      17000] saved checkpoint to /workspace/22_2D_Helmholtz_HardBC/outputs
# 2024-03-03 08:33:47,241 - INFO - [step:      17000] loss:  2.797e-02, time/iteration:  2.124e+02 ms
# 2024-03-03 08:33:54,967 - INFO - [step:      17100] loss:  2.692e-02, time/iteration:  7.725e+01 ms
# 2024-03-03 08:34:04,112 - INFO - [step:      17200] loss:  2.521e-02, time/iteration:  9.142e+01 ms
# 2024-03-03 08:34:11,885 - INFO - [step:      17300] loss:  3.111e-02, time/iteration:  7.768e+01 ms
# 2024-03-03 08:34:19,676 - INFO - [step:      17400] loss:  2.892e-02, time/iteration:  7.790e+01 ms
# 2024-03-03 08:34:27,744 - INFO - [step:      17500] loss:  3.168e-02, time/iteration:  8.066e+01 ms
# 2024-03-03 08:34:36,478 - INFO - [step:      17600] loss:  2.581e-02, time/iteration:  8.731e+01 ms
# 2024-03-03 08:34:44,445 - INFO - [step:      17700] loss:  2.610e-02, time/iteration:  7.965e+01 ms
# 2024-03-03 08:34:52,764 - INFO - [step:      17800] loss:  3.008e-02, time/iteration:  8.317e+01 ms
# 2024-03-03 08:35:01,080 - INFO - [step:      17900] loss:  2.560e-02, time/iteration:  8.315e+01 ms
# 2024-03-03 08:35:10,765 - INFO - [step:      18000] record constraint batch time:  9.393e-02s
# 2024-03-03 08:35:22,994 - INFO - [step:      18000] record validators time:  1.223e+01s
# 2024-03-03 08:35:23,101 - INFO - [step:      18000] saved checkpoint to /workspace/22_2D_Helmholtz_HardBC/outputs
# 2024-03-03 08:35:23,102 - INFO - [step:      18000] loss:  2.665e-02, time/iteration:  2.202e+02 ms
# 2024-03-03 08:35:31,496 - INFO - [step:      18100] loss:  2.927e-02, time/iteration:  8.393e+01 ms
# 2024-03-03 08:35:39,548 - INFO - [step:      18200] loss:  2.729e-02, time/iteration:  8.051e+01 ms
# 2024-03-03 08:35:47,906 - INFO - [step:      18300] loss:  2.518e-02, time/iteration:  8.355e+01 ms
# 2024-03-03 08:35:56,469 - INFO - [step:      18400] loss:  2.446e-02, time/iteration:  8.562e+01 ms
# 2024-03-03 08:36:04,843 - INFO - [step:      18500] loss:  2.613e-02, time/iteration:  8.372e+01 ms
# 2024-03-03 08:36:12,840 - INFO - [step:      18600] loss:  2.577e-02, time/iteration:  7.993e+01 ms
# 2024-03-03 08:36:21,497 - INFO - [step:      18700] loss:  2.582e-02, time/iteration:  8.655e+01 ms
# 2024-03-03 08:36:29,742 - INFO - [step:      18800] loss:  2.477e-02, time/iteration:  8.244e+01 ms
# 2024-03-03 08:36:38,761 - INFO - [step:      18900] loss:  2.560e-02, time/iteration:  9.017e+01 ms
# 2024-03-03 08:36:59,765 - INFO - [step:      19000] record validators time:  1.224e+01s
# 2024-03-03 08:36:59,885 - INFO - [step:      19000] saved checkpoint to /workspace/22_2D_Helmholtz_HardBC/outputs
# 2024-03-03 08:36:59,888 - INFO - [step:      19000] loss:  2.738e-02, time/iteration:  2.112e+02 ms
# 2024-03-03 08:37:07,338 - INFO - [step:      19100] loss:  2.627e-02, time/iteration:  7.449e+01 ms
# 2024-03-03 08:37:15,513 - INFO - [step:      19200] loss:  2.738e-02, time/iteration:  8.173e+01 ms
# 2024-03-03 08:37:22,775 - INFO - [step:      19300] loss:  2.526e-02, time/iteration:  7.260e+01 ms
# 2024-03-03 08:37:32,541 - INFO - [step:      19400] loss:  2.766e-02, time/iteration:  9.764e+01 ms
# 2024-03-03 08:37:42,096 - INFO - [step:      19500] loss:  2.848e-02, time/iteration:  9.552e+01 ms
# 2024-03-03 08:37:50,737 - INFO - [step:      19600] loss:  2.475e-02, time/iteration:  8.639e+01 ms
# 2024-03-03 08:38:00,143 - INFO - [step:      19700] loss:  2.433e-02, time/iteration:  9.403e+01 ms
# 2024-03-03 08:38:08,925 - INFO - [step:      19800] loss:  2.437e-02, time/iteration:  8.780e+01 ms
# 2024-03-03 08:38:18,167 - INFO - [step:      19900] loss:  2.325e-02, time/iteration:  9.240e+01 ms
# 2024-03-03 08:38:27,347 - INFO - [step:      20000] record constraint batch time:  8.903e-02s
# 2024-03-03 08:38:40,349 - INFO - [step:      20000] record validators time:  1.300e+01s
# 2024-03-03 08:38:40,395 - INFO - [step:      20000] saved checkpoint to /workspace/22_2D_Helmholtz_HardBC/outputs
# 2024-03-03 08:38:40,397 - INFO - [step:      20000] loss:  2.547e-02, time/iteration:  2.223e+02 ms
# 2024-03-03 08:38:40,398 - INFO - [step:      20000] reached maximum training steps, finished training!

# %% [markdown]
# ### 后处理以及可视化
#
# 对于jupyter，比较方便的方法是使用matplotlib
#
# 此外，还可以使用tensorboard以及Paraview
#
# ![u](./outputs/validators/validator_u.png)
